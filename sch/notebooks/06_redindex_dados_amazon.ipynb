# %%
import pandas as pd
from os import path as osp

# %%
NULL_STRING = '#NULLO#'

# %%
file_amazon = '../datasets/amazon.parquet.gzip'
file_amazon_reindexed = '../datasets/amazon_reindexed.parquet'

if osp.exists(file_amazon_reindexed):
    print(f'Read existing file {file_amazon_reindexed}.')
    df_amazon = pd.read_parquet(file_amazon_reindexed)
    
else:
    print(f'Read existing file {file_amazon}, redindex and save to new file {file_amazon_reindexed}')
    df_amazon = pd.read_parquet(file_amazon)
    # fill na values with NULL_STRING
    df_amazon = df_amazon.fillna(NULL_STRING)
    # reindex
    df_amazon = df_amazon.reset_index(drop=True)
    # save to new file
    df_amazon.to_parquet(file_amazon_reindexed,compression='gzip')
df_amazon
# Out:
# Read existing file ../datasets/amazon.parquet.gzip, redindex and save to new file ../datasets/amazon_reindexed.parquet
#                                                      Link Palavra_Chave  \
# 0       https://www.amazon.com.br/Especiais-Cinematic-...         drone
# 1       https://www.amazon.com.br/Motores-Escova-Conju...         drone
# 2       https://www.amazon.com.br/Armazenamento-Protet...         drone
# 3       https://www.amazon.com.br/EQUSS-V-strom-Motoci...         drone
# 4       https://www.amazon.com.br/remote-control-brush...         drone
# ...                                                   ...           ...
# 151777  https://www.amazon.com.br/Fotografia-Quadcopte...
# 151778  https://www.amazon.com.br/YITRE-Carregador-Eme...
# 151779  https://www.amazon.com.br/reforço-Amplificador...
# 151780  https://www.amazon.com.br/Hosioe-Altitude-Qudc...
# 151781  https://www.amazon.com.br/Livros-Treinando-Ort...
#
#                              cat_0                             cat_1  \
# 0         Eletrônicos e Tecnologia                    Câmeras e Foto
# 1         Eletrônicos e Tecnologia                    Câmeras e Foto
# 2               Brinquedos e Jogos     Brinquedos de Controle Remoto
# 3         Eletrônicos e Tecnologia                    Câmeras e Foto
# 4         Eletrônicos e Tecnologia                    Câmeras e Foto
# ...                            ...                               ...
# 151777    Eletrônicos e Tecnologia                    Câmeras e Foto
# 151778    Eletrônicos e Tecnologia           Celulares e Comunicação
# 151779  Computadores e Informática   Dispositivos de Conexão em Rede
# 151780    Eletrônicos e Tecnologia                    Câmeras e Foto
# 151781                      Livros  Educação, Referência e Didáticos
#
#               cat_2                   cat_3                   cat_4    cat_5  \
# 0        Acessórios                 Filtros                 #NULLO#  #NULLO#
# 1        Acessórios  Acessórios para Drones                 #NULLO#  #NULLO#
# 2           #NULLO#                 #NULLO#                 #NULLO#  #NULLO#
# 3        Acessórios  Acessórios para Drones                 #NULLO#  #NULLO#
# 4        Acessórios  Acessórios para Drones                 #NULLO#  #NULLO#
# ...             ...                     ...                     ...      ...
# 151777   Acessórios  Acessórios para Drones                 #NULLO#  #NULLO#
# 151778   Acessórios            Carregadores  Carregadores Portáteis  #NULLO#
# 151779  Repetidores                 #NULLO#                 #NULLO#  #NULLO#
# 151780   Acessórios  Acessórios para Drones                 #NULLO#  #NULLO#
# 151781      #NULLO#                 #NULLO#                 #NULLO#  #NULLO#
#
#                              Marca               Modelo  ...  \
# 0                          Odorkle              #NULLO#  ...
# 1                           Airshi  Airshimowq96xigy-11  ...
# 2                          Zhjvihx              #NULLO#  ...
# 3                            Equss                EQUSS  ...
# 4                           Uxsiya     Uxsiyay49ekqxi1t  ...
# ...                            ...                  ...  ...
# 151777                    Iytefeki                    1  ...
# 151778                       YITRE      Yitrewamu3eqnyf  ...
# 151779             E22629EU-2mdbrj                       ...
# 151780  HosioeBRBBYH128RM13029-1-1                       ...
# 151781                     #NULLO#              #NULLO#  ...
#
#                                         Vendedor        Data_Inclusão  Ativo  \
# 0                                        Lantacy  2024-03-06 01:49:12   True
# 1                                        Aiterwu  2024-03-06 01:49:00   True
# 2                                     Zhjvihx-US  2024-03-06 01:48:46   True
# 3       Dengzhoushilianzhouqichepeijianshanghang  2024-03-06 01:48:26   True
# 4                                    Mseinope-US  2024-03-06 01:48:14   True
# ...                                          ...                  ...    ...
# 151777                                    Amazon  2023-08-11 18:42:20  False
# 151778                                  Ginyia U  2023-08-11 18:42:20  False
# 151779                                   moedoll  2023-08-11 18:42:20  False
# 151780                               baiyihuiBYH  2023-08-11 18:42:20  False
# 151781                                    Amazon  2023-08-11 18:42:20  False
#
#                                       Descrição_Principal  \
# 0       Modelo aplicável: este filtro de listras azuis...
# 1       Fonte de alimentação: este motor sem escova de...
# 2       Válvula de Alívio de Pressão: Equipada com vál...
# 3       [Super Grip] - Design criativo, quatro suporte...
# 4                                                 #NULLO#
# ...                                                   ...
# 151777  ✌Experimente a beleza do mundo: este drone pos...
# 151778                                            #NULLO#
# 151779                                            #NULLO#
# 151780  Função: para cima / para baixo, para frente / ...
# 151781                                            #NULLO#
#
#                                             Link_Vendedor Preço_Original  \
# 0       https://www.amazon.com.br/gp/help/seller/at-a-...        #NULLO#
# 1       https://www.amazon.com.br/gp/help/seller/at-a-...        #NULLO#
# 2       https://www.amazon.com.br/gp/help/seller/at-a-...        #NULLO#
# 3       https://www.amazon.com.br/gp/help/seller/at-a-...        #NULLO#
# 4       https://www.amazon.com.br/gp/help/seller/at-a-...        #NULLO#
# ...                                                   ...            ...
# 151777                          https://www.amazon.com.br        #NULLO#
# 151778  https://www.amazon.com.br/gp/help/seller/at-a-...        #NULLO#
# 151779  https://www.amazon.com.br/gp/help/seller/at-a-...        #NULLO#
# 151780  https://www.amazon.com.br/gp/help/seller/at-a-...        #NULLO#
# 151781                          https://www.amazon.com.br        #NULLO#
#
#        Qtd_disponível Qtd_vendidos Desconto   Estado
# 0             #NULLO#      #NULLO#  #NULLO#  #NULLO#
# 1             #NULLO#      #NULLO#  #NULLO#  #NULLO#
# 2             #NULLO#      #NULLO#  #NULLO#  #NULLO#
# 3             #NULLO#      #NULLO#  #NULLO#  #NULLO#
# 4             #NULLO#      #NULLO#  #NULLO#  #NULLO#
# ...               ...          ...      ...      ...
# 151777        #NULLO#      #NULLO#  #NULLO#  #NULLO#
# 151778        #NULLO#      #NULLO#  #NULLO#  #NULLO#
# 151779        #NULLO#      #NULLO#  #NULLO#  #NULLO#
# 151780        #NULLO#      #NULLO#  #NULLO#  #NULLO#
# 151781        #NULLO#      #NULLO#  #NULLO#  #NULLO#
#
# [151782 rows x 32 columns]

# %%
for col in df_amazon.columns:
    print(col)
# Out:
# Link
# Palavra_Chave
# cat_0
# cat_1
# cat_2
# cat_3
# cat_4
# cat_5
# Marca
# Modelo
# Categoria
# Nome
# EAN
# Certificado_de_Homologação
# Preço
# Avaliações
# Nota
# Data_Atualização
# Imagem
# Características
# Descrição
# Imagens
# Vendedor
# Data_Inclusão
# Ativo
# Descrição_Principal
# Link_Vendedor
# Preço_Original
# Qtd_disponível
# Qtd_vendidos
# Desconto
# Estado

# %%
columns_to_keep = ['cat_0','cat_1','cat_2','cat_3','cat_4','cat_5']
df_amazon['cat_full']=df_amazon[columns_to_keep].apply(lambda row: '_'.join(row),axis=1)
df_amazon['cat_full'].head(5)
# Out:
# 0    Eletrônicos e Tecnologia_Câmeras e Foto_Acessó...
# 1    Eletrônicos e Tecnologia_Câmeras e Foto_Acessó...
# 2    Brinquedos e Jogos_Brinquedos de Controle Remo...
# 3    Eletrônicos e Tecnologia_Câmeras e Foto_Acessó...
# 4    Eletrônicos e Tecnologia_Câmeras e Foto_Acessó...
# Name: cat_full, dtype: object

# %%
df_amazon.cat_full.value_counts()
# Out:
# cat_full
# #NULLO#_#NULLO#_#NULLO#_#NULLO#_#NULLO#_#NULLO#                                                                                100406
# Eletrônicos e Tecnologia_Celulares e Comunicação_Celulares e Smartphones_#NULLO#_#NULLO#_#NULLO#                                 6167
# Eletrônicos e Tecnologia_Celulares e Comunicação_Acessórios_Manutenção e Reparos_Peças de Reposição_#NULLO#                      6097
# Eletrônicos e Tecnologia_Câmeras e Foto_Acessórios_Acessórios para Drones_#NULLO#_#NULLO#                                        5208
# Eletrônicos e Tecnologia_Fones de Ouvido e Acessórios_Fones de Ouvido_#NULLO#_#NULLO#_#NULLO#                                    1808
#                                                                                                                                 ...
# Brinquedos e Jogos_Brinquedos de Controle Remoto_Veículos Operados Por Controle Remoto e Aplicativo_#NULLO#_#NULLO#_#NULLO#         1
# CD e Vinil_Indie e Alternativa_Indie e Lo-Fi_Indie Rock_#NULLO#_#NULLO#                                                             1
# Papelaria e Escritório_Arte e Artesanato_#NULLO#_#NULLO#_#NULLO#_#NULLO#                                                            1
# Brinquedos e Jogos_Brinquedos Educativos_Kits de Ciência_#NULLO#_#NULLO#_#NULLO#                                                    1
# Livros_Educação, Referência e Didáticos_#NULLO#_#NULLO#_#NULLO#_#NULLO#                                                             1
# Name: count, Length: 607, dtype: int64

# %%
df_cat_count = df_amazon.cat_0.value_counts()
df_cat_count
# Out:
# cat_0
# #NULLO#                                                 100406
# Eletrônicos e Tecnologia                                 39062
# Computadores e Informática                               11194
# Games e Consoles                                           253
# Casa                                                       125
# Moda                                                       124
# Ferramentas e Materiais de Construção                       88
# Brinquedos e Jogos                                          76
# Automotivo                                                  65
# Instrumentos Musicais                                       62
# Papelaria e Escritório                                      46
# Beleza                                                      44
# Esporte, Aventura e Lazer                                   37
# Eletrônicos para Carros e Veículos                          34
# Acessórios Eletrônicos para Carros                          30
# Jardim e Piscina                                            25
# DVD e Blu-ray                                               20
# Livros                                                      16
# Produtos Industriais e Científicos                          16
# CD e Vinil                                                  15
# Cozinha                                                     13
# Loja Kindle                                                  9
# Saúde e Bem-Estar                                            6
# Bebês                                                        5
# Proteção e Segurança                                         4
# Pet Shop                                                     2
# Equipamentos para Esportes ao Ar Livre e de Aventura         1
# Produtos Laboratoriais e Científicos                         1
# Peças para Automóveis                                        1
# Dispositivos Amazon e Acessórios                             1
# Alimentos e Bebidas                                          1
# Name: count, dtype: Int64

# %%
columns_to_keep = ['cat_0','cat_1','cat_2','cat_3','cat_4','cat_5','cat_full','Nome']
df_cat = df_amazon[df_amazon['cat_0']!=NULL_STRING][columns_to_keep]
df_cat = df_cat.groupby(columns_to_keep[:-1],as_index=False).count().sort_values(by='Nome',ascending=False)

file_cat_to_label = '../datasets/cat_to_label_count.xlsx'
if osp.exists(file_cat_to_label):
    file_cat_to_label_csv = file_cat_to_label.replace('xlsx', 'csv')
    print(f'Alert! File {file_cat_to_label} exists. Save to file{file_cat_to_label_csv}')
    df_cat.to_csv(file_cat_to_label_csv,index=False,sep=';')
else:    
    print(f'Save to file{file_cat_to_label}')
    df_cat.to_excel(file_cat_to_label,index=False)
df_cat
# Out:
# Save to file../datasets/cat_to_label_count.xlsx
#                           cat_0  \
# 304    Eletrônicos e Tecnologia
# 294    Eletrônicos e Tecnologia
# 314    Eletrônicos e Tecnologia
# 372    Eletrônicos e Tecnologia
# 149  Computadores e Informática
# ..                          ...
# 425   Esporte, Aventura e Lazer
# 428   Esporte, Aventura e Lazer
# 432   Esporte, Aventura e Lazer
# 433   Esporte, Aventura e Lazer
# 605           Saúde e Bem-Estar
#
#                                                  cat_1  \
# 304                            Celulares e Comunicação
# 294                            Celulares e Comunicação
# 314                                     Câmeras e Foto
# 372                       Fones de Ouvido e Acessórios
# 149                                         Acessórios
# ..                                                 ...
# 425  Equipamentos para Esportes ao Ar Livre e de Av...
# 428                                 Esportes Aquáticos
# 432                                 Esportes Aquáticos
# 433                                  Esportes com Bola
# 605                         Máscaras e Artigos Médicos
#
#                                cat_2                       cat_3  \
# 304          Celulares e Smartphones                     #NULLO#
# 294                       Acessórios        Manutenção e Reparos
# 314                       Acessórios      Acessórios para Drones
# 372                  Fones de Ouvido                     #NULLO#
# 149               Cabos e Acessórios                       Cabos
# ..                               ...                         ...
# 425           Escalada e Montanhismo                     #NULLO#
# 428                 Lanchas e Barcos    Eletrônicos e Acessórios
# 432                          Natação                      Óculos
# 433                            Vôlei     Equipamento de Proteção
# 605  Máscaras de Tecido e Acessórios  Máscaras Faciais de Tecido
#
#                   cat_4    cat_5  \
# 304             #NULLO#  #NULLO#
# 294  Peças de Reposição  #NULLO#
# 314             #NULLO#  #NULLO#
# 372             #NULLO#  #NULLO#
# 149           Cabos USB  #NULLO#
# ..                  ...      ...
# 425             #NULLO#  #NULLO#
# 428             #NULLO#  #NULLO#
# 432             #NULLO#  #NULLO#
# 433          Joelheiras  #NULLO#
# 605             #NULLO#  #NULLO#
#
#                                               cat_full  Nome
# 304  Eletrônicos e Tecnologia_Celulares e Comunicaç...  6167
# 294  Eletrônicos e Tecnologia_Celulares e Comunicaç...  6097
# 314  Eletrônicos e Tecnologia_Câmeras e Foto_Acessó...  5208
# 372  Eletrônicos e Tecnologia_Fones de Ouvido e Ace...  1808
# 149  Computadores e Informática_Acessórios_Cabos e ...  1719
# ..                                                 ...   ...
# 425  Esporte, Aventura e Lazer_Equipamentos para Es...     1
# 428  Esporte, Aventura e Lazer_Esportes Aquáticos_L...     1
# 432  Esporte, Aventura e Lazer_Esportes Aquáticos_N...     1
# 433  Esporte, Aventura e Lazer_Esportes com Bola_Vô...     1
# 605  Saúde e Bem-Estar_Máscaras e Artigos Médicos_M...     1
#
# [606 rows x 8 columns]

# %%
columns_to_keep = columns_to_keep = ['cat_0','cat_1','cat_2','cat_3','cat_4','cat_5','cat_full','Link','Nome']
df_cat_sample = df_amazon[columns_to_keep]

# map cat with less than 1000 items
map_cat_outros = {cat:'Outros' for cat in df_cat_count[df_cat_count<1000].index}
df_cat_sample.loc[:,'cat_full'] = df_cat_sample[['cat_0','cat_full']].apply(lambda cat: map_cat_outros[cat['cat_0']] if cat['cat_0'] in map_cat_outros.keys() else cat['cat_full'],axis=1)

df_cat_sample = df_cat_sample.groupby('cat_full').sample(10,replace=True).drop_duplicates()
file_cat_sample = '../datasets/cat_to_label_sample.xlsx'
if osp.exists(file_cat_sample):
    file_cat_sample_csv = file_cat_sample.replace('xlsx','csv')
    print(f'Alert! File {file_cat_sample} exists. Save to file {file_cat_sample_csv}')
    df_cat_sample.to_csv(file_cat_sample_csv,index=False,sep=';')
else:    
    print(f'Save to file {file_cat_sample}')
    df_cat_sample.to_excel(file_cat_sample,index=False)
df_cat_sample
# Out:
# Save to file ../datasets/cat_to_label_sample.xlsx
#                                         cat_0  \
# 74353                                 #NULLO#
# 110279                                #NULLO#
# 97422                                 #NULLO#
# 79978                                 #NULLO#
# 98583                                 #NULLO#
# ...                                       ...
# 36168                                    Casa
# 149268  Ferramentas e Materiais de Construção
# 11122                        Games e Consoles
# 20051               Esporte, Aventura e Lazer
# 7083                               Automotivo
#
#                                      cat_1                            cat_2  \
# 74353                              #NULLO#                          #NULLO#
# 110279                             #NULLO#                          #NULLO#
# 97422                              #NULLO#                          #NULLO#
# 79978                              #NULLO#                          #NULLO#
# 98583                              #NULLO#                          #NULLO#
# ...                                    ...                              ...
# 36168                  Decoração para Casa                         Relógios
# 149268                Proteção e Segurança  Sistemas de Segurança para Casa
# 11122                                   PC                       Acessórios
# 20051          Guia de Compras de Esportes                      Eletrônicos
# 7083    Peças e Acessórios para Automóveis            Peças para Automóveis
#
#                         cat_3                            cat_4    cat_5  \
# 74353                 #NULLO#                          #NULLO#  #NULLO#
# 110279                #NULLO#                          #NULLO#  #NULLO#
# 97422                 #NULLO#                          #NULLO#  #NULLO#
# 79978                 #NULLO#                          #NULLO#  #NULLO#
# 98583                 #NULLO#                          #NULLO#  #NULLO#
# ...                       ...                              ...      ...
# 36168           Despertadores                          #NULLO#  #NULLO#
# 149268                Alarmes                          #NULLO#  #NULLO#
# 11122        Fones para Jogos                          #NULLO#  #NULLO#
# 20051                 #NULLO#                          #NULLO#  #NULLO#
# 7083    Baterias e Acessórios  Fontes de Alimentação Portáteis  #NULLO#
#
#                                                cat_full  \
# 74353   #NULLO#_#NULLO#_#NULLO#_#NULLO#_#NULLO#_#NULLO#
# 110279  #NULLO#_#NULLO#_#NULLO#_#NULLO#_#NULLO#_#NULLO#
# 97422   #NULLO#_#NULLO#_#NULLO#_#NULLO#_#NULLO#_#NULLO#
# 79978   #NULLO#_#NULLO#_#NULLO#_#NULLO#_#NULLO#_#NULLO#
# 98583   #NULLO#_#NULLO#_#NULLO#_#NULLO#_#NULLO#_#NULLO#
# ...                                                 ...
# 36168                                            Outros
# 149268                                           Outros
# 11122                                            Outros
# 20051                                            Outros
# 7083                                             Outros
#
#                                                      Link  \
# 74353   https://www.amazon.com.br/PUSOKEI-Alto-falante...
# 110279  https://www.amazon.com.br/Kesoto-peças-macho-a...
# 97422   https://www.amazon.com.br/Smartphone-desbloque...
# 79978   https://www.amazon.com.br/Adaptador-Gigabit-Wi...
# 98583   https://www.amazon.com.br/Drfeify-Propeller-Ho...
# ...                                                   ...
# 36168   https://www.amazon.com.br/Operitacx-Ferramenta...
# 149268  https://www.amazon.com.br/Campainha-campainha-...
# 11122   https://www.amazon.com.br/FONE-OUVIDO-AUDIO-TE...
# 20051   https://www.amazon.com.br/para-Bike-Xoss-Bluet...
# 7083    https://www.amazon.com.br/Bateria-Powerbank-re...
#
#                                                      Nome
# 74353   PUSOKEI Alto-falante Bluetooth pequeno – Alto-...
# 110279  Kesoto 2 peças macho 2,4 GHz 5 Ghz 5,8 Ghz ant...
# 97422   Smartphone desbloqueado, reconhecimento facial...
# 79978   CF 812AC Adaptador Gigabit Wireless USB Wifi A...
# 98583   Drfeify Drone Propeller Holder,2PCS Drone Prop...
# ...                                                   ...
# 36168   Operitacx Batente De Porta Protetor De Parada ...
# 149268  Wyze Campainha de vídeo sem fio Pro (campainha...
# 11122   audio-technica FONE DE OUVIDO SEM FIO OVER-EAR...
# 20051            Gps para Bike Xoss G Bluetooth Mtb Speed
# 7083    Bateria Start Powerbank, Jump Start Pack | Pac...
#
# [2091 rows x 9 columns]

# %%
df_amazon[df_amazon['cat_1'].isin(['Celulares e Comunicação'])][['cat_0','cat_1','cat_2']].value_counts().sort_index()
# Out:
# cat_0                     cat_1                    cat_2
# Eletrônicos e Tecnologia  Celulares e Comunicação  #NULLO#                           14
#                                                    Acessórios                     14398
#                                                    Celulares de Teclas Grandes        9
#                                                    Celulares e Smartphones         6167
# Name: count, dtype: int64

# %%
df_amazon[(df_amazon['cat_1']=='Celulares e Comunicação')&(df_amazon['cat_2']=='Acessórios')][['cat_0','cat_1','cat_2','cat_3']].value_counts().sort_index()
# Out:
# cat_0                     cat_1                    cat_2       cat_3
# Eletrônicos e Tecnologia  Celulares e Comunicação  Acessórios  #NULLO#                                922
#                                                                Acessórios de Carros                    87
#                                                                Acessórios de Foto e Vídeo             112
#                                                                Acessórios para Jogos                  160
#                                                                Amplificadores de Sinal                 98
#                                                                Apoios                                  49
#                                                                Cabos e Adaptadores                     33
#                                                                Canetas Stylus                          98
#                                                                Capas                                 2401
#                                                                Carregadores                          3803
#                                                                Cordões e Tiras de Pulso                17
#                                                                Decoração                               16
#                                                                Expansores e Ampliadores de Tela        26
#                                                                Grips                                   17
#                                                                Headsets Bluetooth de Ouvido Único      21
#                                                                Manutenção e Reparos                  6371
#                                                                Porta-cartões Adesivos                   4
#                                                                Skins Decorativas e de Proteção         17
#                                                                Smartwatches e Acessórios              111
#                                                                Suportes                                35
# Name: count, dtype: int64

# %%
df_amazon[df_amazon['cat_full'].str.contains('Smartwatches')]['cat_full'].value_counts()
# Out:
# cat_full
# Eletrônicos e Tecnologia_Wearables_Smartwatches_#NULLO#_#NULLO#_#NULLO#                                  308
# Eletrônicos e Tecnologia_Celulares e Comunicação_Acessórios_Smartwatches e Acessórios_#NULLO#_#NULLO#    111
# Name: count, dtype: int64

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string

stop_words = stopwords.words('portuguese')
stop_words.extend(stopwords.words('english'))
stop_words.extend(list(string.punctuation))

words = word_tokenize('Mingzhe Transmissor de controle remoto FS-CT6B com receptor . FS-R6B 2.4G. 6CH para RC carro barco quadricóptero planador helicóptero')
print(words)
wc = [w for w in words if w not in stop_words]
print(wc)
# Out:
# ['Mingzhe', 'Transmissor', 'de', 'controle', 'remoto', 'FS-CT6B', 'com', 'receptor', '.', 'FS-R6B', '2.4G', '.', '6CH', 'para', 'RC', 'carro', 'barco', 'quadricóptero', 'planador', 'helicóptero']
# ['Mingzhe', 'Transmissor', 'controle', 'remoto', 'FS-CT6B', 'receptor', 'FS-R6B', '2.4G', '6CH', 'RC', 'carro', 'barco', 'quadricóptero', 'planador', 'helicóptero']

# %%
word_tokenize('Pulse Wave 2 20w BT/AUX/SD/TWS IPX6 Camuflada - SP374')
# Out:
# ['Pulse',
#  'Wave',
#  '2',
#  '20w',
#  'BT/AUX/SD/TWS',
#  'IPX6',
#  'Camuflada',
#  '-',
#  'SP374']
